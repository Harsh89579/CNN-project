# %%
import matplotlib.pyplot as plt
y = (10,20,30,25,53)
x = ["harsh","hina","meina","harry","siya"]
plt.bar(x,y,color= "black")
plt.show()

# %%
import pandas as pd

data = {"Name":["harsh","himanshu","siya"],
       "Age":[20,30,22],
       "salary":[50000,30000,45000]}
